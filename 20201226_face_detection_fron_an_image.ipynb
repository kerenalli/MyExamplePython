# %% [markdown]
# <a href="https://colab.research.google.com/github/kerenalli/MyExamplePython/blob/main/20201226_face_detection_fron_an_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 #opencv itself
import numpy as np # matrix manipulations

#the following are to do with this interactive notebook code
# %matplotlib inline 
from matplotlib import pyplot as plt # this lets you draw inline pictures in the notebooks
import pylab # this allows you to control figure size

# %%
#source image
imagePath = "/content/faces.jpg"
image = cv2.imread(imagePath)
plt.imshow(image)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.3,
    minNeighbors=3,
    minSize=(30, 30)
)

print("[INFO] Found {0} Faces.".format(len(faces)))
#detect and crop the faces of an image
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
    roi_color = image[y:y + h, x:x + w]
    print("[INFO] Object found. Saving locally.")
    cv2.imwrite(str(w) + str(h) + '_faces.jpg', roi_color)
status = cv2.imwrite('faces_detected.jpg', image)

#Display the detected faces
print("\nDetetcted faces afre: \n")
imagePath1 = "/content/faces_detected.jpg"
image2 = cv2.imread(imagePath1)
plt.imshow(image2)

print("[INFO] Image faces_detected.jpg written to filesystem: ", status)
# Out:
# [INFO] Found 16 Faces.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
# [INFO] Object found. Saving locally.
#
# Detetcted faces afre:
#
# [INFO] Image faces_detected.jpg written to filesystem:  True
